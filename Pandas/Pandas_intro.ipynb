# %%
import pandas as pd

# %%
series = pd.Series(["car1", "car2","car3"])

# %%
series
# Out:
# 0    car1
# 1    car2
# 2    car3
# dtype: object

# %%
colours = pd.Series(["red", "black", "green"])
colours
# Out:
# 0      red
# 1    black
# 2    green
# dtype: object

# %%
carColoumns = pd.DataFrame({"Name":series,"Rang":colours})

# %%
carColoumns
# Out:
#          0
# red    NaN
# black  NaN
# green  NaN

# %%
carColoumns
# Out:
#          0
# red    NaN
# black  NaN
# green  NaN

# %%
carColoumns
# Out:
#          0
# red    NaN
# black  NaN
# green  NaN

# %%
CarLists=pd.DataFrame({"Name":series, "Colour":colours})
CarLists
# Out:
#    Name Colour
# 0  car1    red
# 1  car2  black
# 2  car3  green

# %%
ls
# Out:
# Pandas_intro.ipynb
# Untitled.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# business-financial-data-march-2023-quarter-csv.csv
# env/

# %%
business_data = pd.read_csv("business-financial-data-march-2023-quarter-csv.csv")
business_data
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars
# 1       BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars
# 2       BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars
# 3       BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars
# 4       BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars
# ...               ...      ...         ...        ...    ...      ...
# 6670     BDCQ.SF8RSCA  2022.03     493.945        NaN      F  Dollars
# 6671     BDCQ.SF8RSCA  2022.06     579.955        NaN      F  Dollars
# 6672     BDCQ.SF8RSCA  2022.09     609.161        NaN      F  Dollars
# 6673     BDCQ.SF8RSCA  2022.12     518.615        NaN      F  Dollars
# 6674     BDCQ.SF8RSCA  2023.03     663.630        NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 0             6  Business Data Collection - BDC
# ...

# %%
Sample_bank_data= pd.read_csv("Sample_bank_data.csv")
Sample_bank_data
# Out:
#    Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0     BDCQ.SF1AA2CA  2016.06    1116.386         NaN      F  Dollars
# 1     BDCQ.SF1AA2CA  2016.09    1070.874         NaN      F  Dollars
# 2     BDCQ.SF1AA2CA  2016.12    1054.408         NaN      F  Dollars
# 3     BDCQ.SF1AA2CA  2017.03    1010.665         NaN      F  Dollars
# 4     BDCQ.SF1AA2CA  2017.06    1233.700         NaN      F  Dollars
# 5     BDCQ.SF1AA2CA  2017.09    1282.436         NaN      F  Dollars
# 6     BDCQ.SF1AA2CA  2017.12    1290.820         NaN      F  Dollars
# 7     BDCQ.SF1AA2CA  2018.03    1412.007         NaN      F  Dollars
# 8     BDCQ.SF1AA2CA  2018.06    1488.055         NaN      F  Dollars
# 9     BDCQ.SF1AA2CA  2018.09    1497.678         NaN      F  Dollars
# 10    BDCQ.SF1AA2CA  2018.12    1570.507         NaN      F  Dollars
# 11    BDCQ.SF1AA2CA  2019.03    1393.749         NaN      F  Dollars
# 12    BDCQ.SF1AA2CA  2019.06    1517.143         NaN      F  Dollars
# ...

# %%
cd .csv
# Out:
# [Errno 2] No such file or directory: '.csv'
# /Users/ankit/Desktop/sample_project

# %%
ls
# Out:
# Pandas_intro.ipynb
# Sample_bank_data.csv
# Untitled.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# business-financial-data-march-2023-quarter-csv.csv
# business-financial-data-march-csv.csv
# env/

# %%
cd ..
# Out:
# /Users/ankit/Desktop

# %%
ls
# Out:
# 11/                            Projects/
# CT20234189591_Application.pdf  SS/
# College Project/               To-do-list/
# Courses/                       WebDev/
# Flask-Angular/                 XML_extract/
# Flask-Angular-Web-Application/ YelpCamp/
# Learning_WebDev/               lets-do-it/
# Learning_mongoDB/              me.docx
# Mayank/                        pendrive/
# Portfolio/                     sample_project/
# Project/

# %%
cd sample_project/
# Out:
# /Users/ankit/Desktop/sample_project

# %%
ls
# Out:
# Pandas_intro.ipynb
# Sample_bank_data.csv
# Untitled.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# business-financial-data-march-2023-quarter-csv.csv
# business-financial-data-march-csv.csv
# env/

# %%
bank2Data=pd.read_csv("business-financial-data-march-2023-quarter-csv.csv")
bank2Data=bank2Data.head(9)

# %%
bank2Data
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0    BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars          6
# 1    BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars          6
# 2    BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars          6
# 3    BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars          6
# 4    BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars          6
# 5    BDCQ.SF1AA2CA  2017.09    1282.436        NaN      F  Dollars          6
# 6    BDCQ.SF1AA2CA  2017.12    1290.820        NaN      F  Dollars          6
# 7    BDCQ.SF1AA2CA  2018.03    1412.007        NaN      F  Dollars          6
# 8    BDCQ.SF1AA2CA  2018.06    1488.055        NaN      F  Dollars          6
#
#                           Subject  \
# 0  Business Data Collection - BDC
# 1  Business Data Collection - BDC
# 2  Business Data Collection - BDC
# 3  Business Data Collection - BDC
# ...

# %%
bank2Data.to_csv("NewbankData.csv")
NewbankData
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 bank2Data.to_csv("NewbankData.csv")
# ----> 2 NewbankData
#
# NameError: name 'NewbankData' is not defined

# %%
bank2Data
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0    BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars          6
# 1    BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars          6
# 2    BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars          6
# 3    BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars          6
# 4    BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars          6
# 5    BDCQ.SF1AA2CA  2017.09    1282.436        NaN      F  Dollars          6
# 6    BDCQ.SF1AA2CA  2017.12    1290.820        NaN      F  Dollars          6
# 7    BDCQ.SF1AA2CA  2018.03    1412.007        NaN      F  Dollars          6
# 8    BDCQ.SF1AA2CA  2018.06    1488.055        NaN      F  Dollars          6
#
#                           Subject  \
# 0  Business Data Collection - BDC
# 1  Business Data Collection - BDC
# 2  Business Data Collection - BDC
# 3  Business Data Collection - BDC
# ...

# %%
bank2Data.plot()
# Out:
# <Axes: >

# %%
bank2Data.Data_value.plot()
# Out:
# <Axes: >

# %%
bank2Data["Data_value"].plot()
# Out:
# <Axes: >
